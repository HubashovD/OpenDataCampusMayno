# %% [markdown]
# # Технічний воркшоп: "Як створити проект на основі відкритих даних"

# %% [markdown]
# ## Необхідні бібілотеки

# %%
import pandas as pd
import requests
import json
import re

# %% [markdown]
# ## NOMINANTUM

# %% [markdown]
# https://nominatim.org/release-docs/develop/api/Overview/ - Документація
# https://nominatim.openstreetmap.org/reverse?format=json&lat=50.433776&lon=30.540501&zoom=18&addressdetails=1 - приклад даних
# https://nominatim.openstreetmap.org/?addressdetails=1&q=10/8,%D0%93%D1%83%D1%81%D0%BE%D0%B2%D1%81%D1%8C%D0%BA%D0%BE%D0%B3%D0%BE,%D0%B2%D1%83%D0%BB%D0%B8%D1%86%D1%8F,%D0%9A%D0%B8%D1%97%D0%B2&format=json&limit=1 - приклад даних

# %%
# Отримати адресу за координатами

lat = ["50.433776","50.461367","50.44821",]
lon = ["30.540501","30.621157","30.513893",]

house_number = []
road = []
suburb = []
borough = []
city = []


for i in range (0, len(lat)):
    cordinates = requests.get("https://nominatim.openstreetmap.org/reverse?format=json&lat=" + str(lat[i])+"&lon=" + str(lon[i])+"&zoom=18&addressdetails=1").json()
    try:
        try:
            house_number.append(cordinates["address"]["house_number"])
        except:
            house_number.append("null")
        try:
            road.append(cordinates["address"]["road"])
        except:
            road.append("null")
        try:
            suburb.append(cordinates["address"]["suburb"])
        except:
            suburb.append("null")
        try:
            borough.append(cordinates["address"]["borough"])
        except:
            borough.append("null")
        try:
            city.append(cordinates["address"]["city"])
        except:
            city.append("null")
        time.sleep(1)
    except:
        pass
        

packages_df =  pd.DataFrame({"lat" : lat,
                             "lon" : lon,
                             "house_number": house_number,
                             "road": road,                             
                             "suburb": suburb,
                             "borough":borough,
                             "city": city
                            })
packages_df
# Out:
#          lat        lon house_number                   road  \
# 0  50.433776  30.540501         10/8     Гусовського вулиця
# 1  50.461367  30.621157          19а  Андрія Малишка вулиця
# 2   50.44821  30.513893           42   Володимирська вулиця
#
#                suburb               borough  city
# 0            Печерськ      Печерський район  Київ
# 1  Лівобережний масив    Дніпровський район  Київ
# 2               Центр  Шевченківський район  Київ

# %%
# Отримати координати за адресою
lat_one = []
lon_one = []

for i in range (0, len(city)):
    request = requests.get("https://nominatim.openstreetmap.org/?addressdetails=1&q=" + str(house_number[i]) + "," + str(road[i]) + "," + str(city[i]) + "&format=json&limit=1").json()
    try:
        try:
            lat_one.append(request[0]["lat"])
        except:
            lat_one.append("null")
        try:
            lon_one.append(request[0]["lon"])
        except:
            lon_one.append("null")
    except:
        pass
    
packages_df =  pd.DataFrame({"lat_one" : lat_one,
                             "lon_one" : lon_one,
                             "house_number": house_number,
                             "road": road,                             
                             "city": city
                            })
packages_df
# Out:
#        lat_one             lon_one house_number                   road  city
# 0  50.43386975  30.540575402259474         10/8     Гусовського вулиця  Київ
# 1   50.4614098   30.62113181013427          19а  Андрія Малишка вулиця  Київ
# 2   50.4483922          30.5139104           42   Володимирська вулиця  Київ

# %% [markdown]
# ## Regex

# %% [markdown]
# https://regex101.com/ - інструмент для перевірки регулярних виразів
# https://uk.wikipedia.org/wiki/%D0%A0%D0%B5%D0%B3%D1%83%D0%BB%D1%8F%D1%80%D0%BD%D0%B8%D0%B9_%D0%B2%D0%B8%D1%80%D0%B0%D0%B7 - перелік виразів

# %%
string = "Україна, Київ, вул.Хрещатик,1,01001"

# %%
country

# %% [markdown]
# ## API PROZORRO

# %% [markdown]
# https://prozorro-api-docs.readthedocs.io/uk/latest/authentication.html - Документація
# http://planning.api-docs.openprocurement.org/uk/latest/index.html - плани закупівель Дикументація
#
# https://public.api.openprocurement.org/api/2.5/plans - плани закупівель лістінг
# https://public.api.openprocurement.org/api/2.5/plans/e151afa3529b4e58a33176be57334b0d - окремий план
#
# https://public.api.openprocurement.org/api/2.5/tenders?offset=2015-06-19 - лістінг тендерів
# https://public.api.openprocurement.org/api/2.5/tenders/89efe065b0dc48f38592c74f6ec74092 - окремий тендер

# %%
list__of_tenders = requests.get("https://public.api.openprocurement.org/api/2.5/tenders?offset=2015-06-19").json()
list__of_tenders["data"]

tenders = []

urls = []
titles = []
sums = []

for i in list__of_tenders["data"]:
        tender = requests.get("https://public.api.openprocurement.org/api/2.5/tenders/" + str(i["id"])).json()
        urls.append("https://prozorro.gov.ua/tender/" + str(tender["data"]["tenderID"]))
        titles.append(tender["data"]["title"])
        sums.append(tender["data"]["value"]["amount"])
        

packages_df =  pd.DataFrame({"url" : urls,
                             "title" : titles,
                             "sum": sums
                            })
packages_df
# Out:
#                                                   url  \
# 0   https://prozorro.gov.ua/tender/UA-2015-06-11-0...
# 1   https://prozorro.gov.ua/tender/UA-2015-06-18-0...
# 2   https://prozorro.gov.ua/tender/UA-2015-06-18-0...
# 3   https://prozorro.gov.ua/tender/UA-2015-06-18-0...
# 4   https://prozorro.gov.ua/tender/UA-2015-06-18-0...
# ..                                                ...
# 95  https://prozorro.gov.ua/tender/UA-2015-08-11-0...
# 96  https://prozorro.gov.ua/tender/UA-2015-08-11-0...
# 97  https://prozorro.gov.ua/tender/UA-2015-08-07-0...
# 98  https://prozorro.gov.ua/tender/UA-2015-08-06-0...
# 99  https://prozorro.gov.ua/tender/UA-2015-08-04-0...
#
#                                                 title      sum
# 0                                         Бензин А-95  50000.0
# 1            Послуги з експлуатації спортивних споруд  12960.0
# 2                                Послуги з харчування  26400.0
# 3          Послуги з розміщення іногородніх учасників  16575.0
# 4        Патрон Nammo Schonebeck SK RIFLE MATCH 22 LR  57600.0
# ..                                                ...      ...
# 95                                        мило тверде     50.0
# 96                                 файл канцелярський     80.0
# 97  «Мотузки, канати, шпагат і сіткове полотно, кр...  36799.0
# 98                           Бензин А-92 та Дизпаливо   2630.0
# 99                   Папір офісний формату А4, Клас В   3075.0
#
# [100 rows x 3 columns]

# %% [markdown]
# ## API Data.gov.ua

# %% [markdown]
# https://data.gov.ua/api/3/action/package_list - перелік наборів даних
# https://data.gov.ua/api/3/action/organization_show?id=tax&include_datasets=true - пошук наборів розпорядника
#
# https://data.gov.ua/pages/aboutuser2 - опис АРІ

# %%
#Запит на отримання всіх наборів даних
response = requests.get("https://data.gov.ua/api/3/action/package_list").json()
len(response["result"])
# Out:
# 36159

# %%
#Запит на отримання наборів даних Мінеко

response = requests.get("https://data.gov.ua/api/3/action/organization_show?id=ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny&include_datasets=true").json()
response["result"]
# Out:
# {'users': [{'email_hash': '0fc6f8d5dfe6ed23a7441e022a873ab1',
#    'about': '',
#    'capacity': 'admin',
#    'name': 'default',
#    'created': '2018-08-08T14:04:44.915899',
#    'openid': None,
#    'sysadmin': True,
#    'activity_streams_email_notifications': False,
#    'state': 'active',
#    'number_of_edits': 93937,
#    'display_name': 'default',
#    'fullname': '',
#    'id': '299ffe82-f956-4446-b7e9-19a9bdee4db5',
#    'number_created_packages': 1969},
#   {'email_hash': '38a2c68138415f92207d8bdc4594095e',
#    'about': '',
#    'capacity': 'admin',
#    'name': 'taisa_570',
#    'created': '2018-08-08T19:08:37.979152',
#    'openid': None,
#    'sysadmin': False,
#    'activity_streams_email_notifications': False,
#    'state': 'active',
#    'number_of_edits': 611,
#    'display_name': 'Міндовкілля',
#    'fullname': 'Міндовкілля',
#    'id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'number_created_packages': 35}],
#  'display_name': 'Міністерство захисту довкілля та природних ресурсів України',
#  'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#  'image_display_url': 'https://data.gov.ua/uploads/group/2021-01-25-143959.791841ecoimage.jpg',
#  'package_count': 35,
#  'created': '2018-08-08T19:53:03.447633',
#  'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#  'is_organization': True,
#  'state': 'active',
#  'extras': [],
#  'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#  'groups': [],
#  'type': 'organization',
#  'title': 'Міністерство захисту довкілля та природних ресурсів України',
#  'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#  'packages': [{'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Стеценко Анастасія Олександрівна',
#    'relationships_as_object': [],
#    'tag_string': 'перелік ліцензіатів,небезпечні відходи',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'bashkirtseva@mepr.gov.ua',
#    'num_tags': 2,
#    'update_frequency': 'once a quarter',
#    'id': 'c5a2ab4e-e5f7-452e-9c20-2636dec670d1',
#    'metadata_created': '2018-11-23T10:50:51.973663',
#    'metadata_modified': '2021-04-02T10:41:14.526304',
#    'author': 'taisa_570',
#    'author_email': 'taisa@menr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'license_id': 'cc-by',
#    'type': 'dataset',
#    'num_resources': 2,
#    'title': 'Дані про видані ліцензії на провадження господарської діяльності з поводження з небезпечними відходами та ліцензіатів',
#    'title_chosen': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'relationships_as_subject': [],
#    'name': '0ccdf4ca-4e78-4a12-9fa8-1953b45728e2',
#    'language': 'ua',
#    'isopen': True,
#    'url': None,
#    'notes': 'Відповідно до ЗАКОНУ УКРАЇНИ «Про ліцензування видів господарської діяльності» , виробництво особливо небезпечних хімічних речовин, перелік яких визначається Кабінетом Міністрів України, поводження з небезпечними відходами. Не підлягає ліцензуванню зберігання (накопичення) суб’єктом господарювання утворених ним небезпечних відходів, якщо протягом року з дня утворення небезпечні відходи передаються суб’єктам господарювання, що мають ліцензію на поводження з небезпечними відходами.',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '68d2cdf9-3f0f-4a6d-86e0-ba7e75b48479'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': "Расюк Юрій В'ячеславович",
#    'relationships_as_object': [],
#    'tag_string': 'ліміти,відстріл,полювання,тварини,відлов',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'y.rasyk@mepr.gov.ua',
#    'num_tags': 5,
#    'update_frequency': 'once a year',
#    'id': '1e91f4a8-ab02-459c-ae5d-bd19dbe80bcf',
#    'metadata_created': '2021-03-26T07:27:55.334304',
#    'metadata_modified': '2021-04-01T12:13:27.711639',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Ліміти, норми використання об’єктів тваринного світу (крім водних біоресурсів) та спеціального використання об’єктів тваринного світу (крім водних біоресурсів)',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_23',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Ліміти використання (відстрілу, відлову) диких парнокопитних та хутрових звірів, у сезон полювання 2020-2021 років',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '43d386c3-20da-42cd-bc42-fa72f178962c'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Пойда Микола Сергійович',
#    'relationships_as_object': [],
#    'tag_string': 'найменування підприємства,код сертифіката,термін придатності сертифіката,єдрпоу,дата випуску сертифіката',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'poida@mepr.gov.ua',
#    'num_tags': 5,
#    'update_frequency': 'once a half year',
#    'id': '0696991b-f1fd-4fee-9afc-39aa21983902',
#    'metadata_created': '2021-03-26T07:28:27.221715',
#    'metadata_modified': '2021-03-26T07:31:21.557815',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'license_id': 'cc-by',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Інформація про сертифіковані ліси підприємств, які належать до сфери управління Держлісагентства',
#    'title_chosen': 'false',
#    'groups': [],
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'relationships_as_subject': [],
#    'name': 'mepr_36',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Інформація щодо сертифікованих лісів підприємств, які належать до сфери управління Держлісагентства станом на 01.01.2021',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '5b40b173-5291-4061-a5ec-43f7bcef1a72'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Тарасенко Ольга Володимирівна',
#    'relationships_as_object': [],
#    'tag_string': 'екологія,дозвіл,водні ресурси',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'otarasenko@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a year',
#    'id': 'c1347e58-aa6b-45a3-99f0-32395fbba7ab',
#    'metadata_created': '2021-03-19T06:44:19.514256',
#    'metadata_modified': '2021-03-25T13:07:30.385223',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік дозволів на проведення робіт (крім будівельних на землях водного фонду) в Міндовкілля України',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_21',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік дозволів на проведення робіт (крім будівельних на землях водного фонду) в Міндовкілля України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '9c4df960-685a-465a-b33a-7b23989051e4'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Ващенко Володимир Миколайович головний спеціаліст Відділу поводження з пестицидами та агрохімікатами Мінприроди',
#    'relationships_as_object': [],
#    'tag_string': 'препарат,пестициди,термін реєстрації,агрохімікати',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'VMV@menr.gov.ua',
#    'num_tags': 4,
#    'update_frequency': 'immediately after making changes',
#    'id': '87332c79-1301-4ef9-8114-33087f9ab814',
#    'metadata_created': '2019-06-05T14:10:09.619845',
#    'metadata_modified': '2021-03-25T10:27:30.426884',
#    'author': 'taisa_570',
#    'author_email': 'taisa@menr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік пестицидів і агрохімікатів, дозволених для використання',
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': '389ddb5a-ac73-44bb-9252-f899e4a97588',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Державний реєстр пестицидів і агрохімікатів, дозволених до використання в Україні згідно вимог постанови Кабінету Міністрів України від 21.11.2007 № 1328',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'f3787a40-959a-4821-b5f5-dce05f15a1a3'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Гулай Юлія Іванівна',
#    'relationships_as_object': [],
#    'tag_string': 'природні ресурси,природно-заповідний фонд,ліміти на спеціальне використання',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'gulai@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a quarter',
#    'id': '09646934-980e-42fa-8388-80cd3cdc72c1',
#    'metadata_created': '2021-03-22T06:35:58.469418',
#    'metadata_modified': '2021-03-22T06:36:59.900876',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Ліміти на спеціальне використання природних ресурсів у межах територій та об’єктів природно-заповідного фонду загальнодержавного значення',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_24',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Ліміти на спеціальне використання природних ресурсів у межах територій та об’єктів природно-заповідного фонду загальнодержавного значення',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '56063f88-1f9e-4839-aded-a13dcb3d4049'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Остапченко Лариса Анатоліївна',
#    'relationships_as_object': [],
#    'tag_string': 'терирорії,природно-заповідний фонд,державний кадастр',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'ostapchenko@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a year',
#    'id': 'b82cd3eb-7e9c-49cd-9f26-8fb28ab3dd4e',
#    'metadata_created': '2021-03-22T06:23:48.190147',
#    'metadata_modified': '2021-03-22T06:25:26.035320',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Державний кадастр територій та об’єктів природно-заповідного фонду',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_05',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Державний кадастр територій та об’єктів природно-заповідного фонду України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '1a260a71-a659-4dbe-bd67-daaa94248608'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Відділ атмосферного повітря та екологічного аудиту',
#    'relationships_as_object': [],
#    'tag_string': 'стаціонарними джерелами,забруднюючих речовин,атмосферне повітря',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'podolyak@menr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a quarter',
#    'id': 'd6a0d204-a32c-43c4-a34b-2c7a7b477f5b',
#    'metadata_created': '2018-12-20T13:42:51.099837',
#    'metadata_modified': '2021-03-19T13:04:39.436524',
#    'author': None,
#    'author_email': None,
#    'state': 'active',
#    'version': None,
#    'license_id': 'cc-by',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік дозволів на викиди забруднюючих речовин в атмосферне повітря стаціонарними джерелами об’єктів 1, 2, 3 груп із зазначенням номеру та строку дії',
#    'title_chosen': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'relationships_as_subject': [],
#    'name': 'e64b85e9-a1b4-433f-9b71-1fef1c17636d',
#    'language': 'ua',
#    'isopen': True,
#    'url': None,
#    'notes': 'Перелік суб’єктів господарювання, об’єкт якого належить до першої групи, які отримали дозволи на викиди забруднюючих речовин в атмосферне повітря стаціонарними джерелами в Мінприроди України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '59885ddb-9d36-4225-86bb-f53f0bb4a93d'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Добровольська Оксана Іванівна',
#    'relationships_as_object': [],
#    'tag_string': 'збирання рослин,дозвіл,червона книга україни,добування тварин',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'dobr@mepr.gov.ua',
#    'num_tags': 4,
#    'update_frequency': 'once a year',
#    'id': '6e7bd31b-2540-47d4-93b5-4f6ec4756d1c',
#    'metadata_created': '2021-03-19T12:56:49.837506',
#    'metadata_modified': '2021-03-19T13:00:10.784388',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік дозволів на добування тварин, внесених до Червоної книги України, та дозволів на збирання рослин, внесених до Червоної книги України',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_30',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік виданих Міндовкіллям дозволів на добування тварин, внесених до Червоної книги України, та дозволів на збирання рослин, внесених до Червоної книги України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '1f4b33d2-6cfa-45b3-b86c-ab8673ea4d91'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Пойда Микола Сергійович',
#    'relationships_as_object': [],
#    'tag_string': 'ліс,екологія,моніторинг,довкілля',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'poida@mepr.gov.ua',
#    'num_tags': 4,
#    'update_frequency': 'once a year',
#    'id': '5aea511b-1f95-4fba-b15d-a4bcb3440c7f',
#    'metadata_created': '2021-03-19T12:40:15.718266',
#    'metadata_modified': '2021-03-19T12:44:55.524934',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Дані моніторингу лісів',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_38',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Інформація щодо моніторингу лісів за рік',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'c004bbfb-10a0-4c01-bd26-04ebae108844'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Пойда Микола Сергійович',
#    'relationships_as_object': [],
#    'tag_string': 'лісові пожежі,ліс,екологія',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'poida@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a quarter',
#    'id': '20adc758-c7c1-4d75-ab26-affb8ffed81b',
#    'metadata_created': '2021-03-19T12:25:55.346170',
#    'metadata_modified': '2021-03-19T12:28:23.196840',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Інформація про лісові пожежі',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_37',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Інформація про лісові пожежі на території України, яку надає Міндовкілля',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '2f41f204-7550-4154-b1e7-aa469b2ddcb6'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Чмут Дарина Ігорівна',
#    'relationships_as_object': [],
#    'tag_string': 'до якого організацію внесено до переліку,термін,дата внесення організації до переліку,назва області,код за коатуу,місцезнаходження,прізвище та ініціали керівника,дата виключення організації з переліку',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'chmut@mepr.gov.ua',
#    'num_tags': 8,
#    'update_frequency': 'once a quarter',
#    'id': '4bde128a-3511-4ed5-8fc8-6526e676588f',
#    'metadata_created': '2021-03-05T15:19:24.066523',
#    'metadata_modified': '2021-03-19T11:07:09.276996',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік установ, організацій та закладів, яким надається право на розробку документів, що обґрунтовують обсяги викидів для підприємств, установ, організацій та громадян - суб’єктів підприємницької діяльності',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': '91420a2d-7e1d-4ec9-8c3d-97494301ed1c',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': "Перелік установ, організацій та закладів, які здійснюють розробку документів, що обгрунтовують обсяги викидів для підприємств, установ, організацій та громадян-суб'єктів підприємницької діяльності",
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '9642a556-5f0a-4f15-93f2-bd48c408fce9'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Вовк Ірина Станіславівна, Відділ охорони тваринного світу',
#    'relationships_as_object': [],
#    'tag_string': 'imports,quantity,country of origin of re-export,number of export permit or re-export certificate,exports,source,purpose,species,description,appendix',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'vovk@mepr.gov.ua',
#    'num_tags': 10,
#    'update_frequency': 'more than once a day',
#    'id': '951f60fe-be0c-4589-bc9b-203694175841',
#    'metadata_created': '2019-05-24T13:05:22.469378',
#    'metadata_modified': '2021-03-19T07:03:49.563086',
#    'author': 'taisa_570',
#    'author_email': 'taisa@menr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'license_id': 'cc-by',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік дозволів на імпорт та експорт видів дикої фауни і флори, сертифікатів на пересувні виставки, реекспорт та інтродукцію з моря зазначених зразків, за винятком осетрових риб і виробленої з них продукції',
#    'title_chosen': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'relationships_as_subject': [],
#    'name': '196a9caa-7dd5-4616-a14b-b616592c4325',
#    'language': 'ua',
#    'isopen': True,
#    'url': None,
#    'notes': 'Інформація щодо виданих дозволів на імпорт та експорт видів дикої фауни і флори, сертифікатів на пересувні виставки, реекспорт та інтродукцію з моря зазначених зразків',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '30ef7580-e46b-4a88-a7e9-341a8649346d'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Добровольська Оксана Іванівна',
#    'relationships_as_object': [],
#    'tag_string': 'дозвіл,державна апробація,гмо',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'dobr@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a year',
#    'id': '73f302b7-8a8d-4872-90f8-ff97511b36b4',
#    'metadata_created': '2021-03-19T07:01:26.202617',
#    'metadata_modified': '2021-03-19T07:03:04.722882',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік дозволів на проведення державної апробації (випробування) генетично модифікованих організмів у відкритій системі',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_33',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік  виданих Міндовкіллям дозволів на проведення державної апробації (випробування) генетично модифікованих організмів у відкритій системі ',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '813d75c3-2e15-431f-9ddd-7baebc4e85ad'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Добровольська Оксана Іванівна',
#    'relationships_as_object': [],
#    'tag_string': 'транзит,дозвіл,гмо',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТУ МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'dobr@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a year',
#    'id': '58f44193-762e-41ce-9c84-aa5ff58a4ca1',
#    'metadata_created': '2021-03-19T06:56:33.535809',
#    'metadata_modified': '2021-03-19T06:58:32.093520',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік дозволів на транзитне переміщення не зареєстрованих в Україні генетично модифікованих організмів',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_32',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік дозволів на транзитне переміщення не зареєстрованих в Україні генетично модифікованих організмів виданих Міністерством захисту довкілля та природних ресурсів України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'f46c74fa-635c-40b9-9f8e-fe7df6993043'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Корецька Руслана Олегівна',
#    'relationships_as_object': [],
#    'tag_string': 'штучні зміни стану атмосфери,екологія,дозвіл',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'koretska.r@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a year',
#    'id': 'fc34c50b-9f25-4b08-9903-41d621745a60',
#    'metadata_created': '2021-03-18T12:03:27.981710',
#    'metadata_modified': '2021-03-18T12:06:27.636535',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік дозволів на провадження діяльності, пов’язаної із штучними змінами стану атмосфери та атмосферних явищ у господарських цілях',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_31',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік дозволів на провадження діяльності, пов’язаної із штучними змінами стану атмосфери та атмосферних явищ у господарських цілях',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '1ac232aa-ffab-4218-8ac4-d00223882439'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Фишко Наталія Миколаївна',
#    'relationships_as_object': [],
#    'tag_string': 'тип,категорія,ряд,клас,вид',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'ecosys@mepr.gov.ua',
#    'num_tags': 5,
#    'update_frequency': 'once a year',
#    'id': 'f434da03-4da5-46ad-bc3e-ccc4a0a09377',
#    'metadata_created': '2021-03-04T11:44:02.784644',
#    'metadata_modified': '2021-03-17T06:59:23.665219',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 3,
#    'title': 'Червона книга України',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'b5cdb316-6074-4ef3-a0c5-463ff3a72e68',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Переліків видів тварин та рослин, що заносяться до Червоної книги України, та видів тварин і рослин, що виключені з Червоної книги України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '82d48668-7554-4c26-89d2-4eb1974a7eb3'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Горбатюк Олексій Леонідович',
#    'relationships_as_object': [],
#    'tag_string': 'декларації,дата,відходи',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'gol@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a year',
#    'id': '51aa6a55-5037-4ea5-b4bd-d5d72cef3b27',
#    'metadata_created': '2021-03-09T10:50:13.739471',
#    'metadata_modified': '2021-03-15T12:16:03.507867',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 6,
#    'title': 'Перелік декларацій про відходи, які подаються суб’єктами господарювання',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_27',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'ПОСТАНОВА від 18 лютого 2016 р. № 118 Київ Про затвердження Порядку подання декларації про відходи та її форми',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
# ...
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '3fe74a25-9624-45ef-8990-06f2c4ca8569'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Григорський Олег Ярославович',
#    'relationships_as_object': [],
#    'tag_string': 'відхилення,витрати,факт,курсові різниці,план,валовий продукт',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'o.grigorskiy@mepr.gov.ua',
#    'num_tags': 6,
#    'update_frequency': 'more than once a day',
#    'id': 'de4fb7c5-aaca-46be-a7f0-da2fc3d6c3e3',
#    'metadata_created': '2021-03-05T10:52:52.295816',
#    'metadata_modified': '2021-03-05T10:55:22.161454',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Річні зведені основні фінансові показники виконання фінансових планів підприємств державного та комунального секторів економіки',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_13',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Звіт про виконання фінансового плану \r\n',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'b892adbb-e0c5-47cc-be4b-214b03798997'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Тумак Світлана Василівна',
#    'relationships_as_object': [],
#    'tag_string': 'єдрпоу,назва юридичної особи,адреса',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'tymak@mepr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'once a year',
#    'id': '64c467e5-7d8f-44f5-a50a-001bb34c8caf',
#    'metadata_created': '2021-03-04T23:53:54.292030',
#    'metadata_modified': '2021-03-04T23:55:23.386103',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Перелік установ природно-заповідного фонду, що належить до сфери управління Міндовкілля',
#    'title_chosen': 'false',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_28',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік установ природно-заповідного фонду, що належать до сфери управління Міндовкілля',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'c17035c4-783a-43d0-bc86-0867e6078341'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Добровольська Оксана Іванівна',
#    'relationships_as_object': [],
#    'tag_string': 'рідкотравний,назва асоціації,рідкісні,угруповання,лісів',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'dobr@mepr.gov.ua',
#    'num_tags': 5,
#    'update_frequency': 'once a year',
#    'id': '50f6ed3c-fcce-40ed-850d-2173efb355e0',
#    'metadata_created': '2021-03-04T13:44:31.271955',
#    'metadata_modified': '2021-03-04T15:06:11.456004',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Зелена книга України',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'ccee2f8e-0e74-4ff3-8865-e62e903c520f',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік рослинних угруповань які заносяться та вилучені із Зеленої книги України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'c43be57d-75e3-40d5-8e4b-ad98d85488c6'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Бондаренко Юрій Володимирович',
#    'relationships_as_object': [],
#    'tag_string': 'норма витрати препарату,культура,інсектициди,препарат,рік випро-бувань,акарициди',
#    'purpose_of_collecting_information': 'Постанова  від 4 березня 1996 р. N 295 ',
#    'private': False,
#    'maintainer_email': 'yu_bondarenko@mepr.gov.ua',
#    'num_tags': 6,
#    'update_frequency': 'once a year',
#    'id': '2cc96c96-1725-45df-9e40-9f6ccf1b232d',
#    'metadata_created': '2021-03-04T14:33:21.460963',
#    'metadata_modified': '2021-03-04T14:52:40.605400',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Дані про державні випробування та реєстрацію пестицидів і агрохімікатів',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': 'mepr_06',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Плани державних випробувань пестицидів і агрохімікатів ',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'b96b0386-5773-4fdb-9f7c-038e8b5f7a66'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Добровольська Оксана Іванівна',
#    'relationships_as_object': [],
#    'tag_string': 'рідкотравний,назва асоціації,рідкісні,угруповання,лісів',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'dobr@mepr.gov.ua',
#    'num_tags': 5,
#    'update_frequency': 'once a year',
#    'id': 'ba763c5c-bc89-4715-8260-39a53559aada',
#    'metadata_created': '2021-03-04T13:44:56.257389',
#    'metadata_modified': '2021-03-04T13:48:36.928460',
#    'author': 'taisa_570',
#    'author_email': 'itwork@mepr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Зелена книга України',
#    'title_chosen': 'true',
#    'groups': [],
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': '4f567721-2f47-4095-ab3d-6d9caf4304ad',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Перелік рослинних угруповань які заносяться та вилучені із Зеленої книги України',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': '87ab24c3-4274-48bf-a57a-924f857538e6'},
#   {'owner_org': '27cd857f-fec2-474d-b582-a263033938cb',
#    'maintainer': 'Подоляк Ігор Павлович',
#    'relationships_as_object': [],
#    'tag_string': 'серія та номер сертифіката,номер та дата рішення про внесення,місцезнаходження',
#    'purpose_of_collecting_information': 'ПОСТАНОВА КАБІНЕТE МІНІСТРІВ УКРАЇНИ від 21 жовтня 2015 р. № 835 Київ Про затвердження Положення про набори даних, які підлягають оприлюдненню у формі відкритих даних',
#    'private': False,
#    'maintainer_email': 'podolyak@menr.gov.ua',
#    'num_tags': 3,
#    'update_frequency': 'immediately after making changes',
#    'id': '2fba6fe5-a069-42ef-93b5-f4af2f42abd9',
#    'metadata_created': '2019-04-12T12:43:56.458542',
#    'metadata_modified': '2021-03-04T09:26:23.546197',
#    'author': 'taisa_570',
#    'author_email': 'taisa@menr.gov.ua',
#    'state': 'active',
#    'version': '1.0',
#    'is_datapackage': 'true',
#    'creator_user_id': '94b388a6-6f56-487c-ba29-d5668ece67a2',
#    'type': 'dataset',
#    'num_resources': 1,
#    'title': 'Реєстр екологічних аудиторів та юридичних осіб, що мають право на здійснення екологічного аудиту',
#    'license_id': 'cc-by',
#    'relationships_as_subject': [],
#    'name': '750408d0-4a53-4260-8b39-881d815409dc',
#    'isopen': True,
#    'language': 'ua',
#    'url': None,
#    'notes': 'Інформація щодо екологічних аудиторів, що мають право на здійснення екологічного аудит',
#    'license_title': 'Creative Commons Attribution',
#    'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#    'organization': {'description': 'Міністерство формує та реалізує державну політику у сфері:\r\nохорони навколишнього природного середовища, екологічної та в межах повноважень, передбачених законом, радіаційної, біологічної і генетичної безпеки, у сфері рибного господарства та рибної промисловості, охорони, використання та відтворення водних біоресурсів, регулювання рибальства та безпеки мореплавства суден флоту рибного господарства, лісового та мисливського господарств.',
#     'created': '2018-08-08T19:53:03.447633',
#     'title': 'Міністерство захисту довкілля та природних ресурсів України',
#     'name': 'ministerstvo-ekolohiyi-ta-pryrodnykh-resursiv-ukrayiny',
#     'is_organization': True,
#     'state': 'active',
#     'image_url': '2021-01-25-143959.791841ecoimage.jpg',
#     'revision_id': '77df11c9-3a94-4e12-9e9f-eab272b2919e',
#     'type': 'organization',
#     'id': '27cd857f-fec2-474d-b582-a263033938cb',
#     'approval_status': 'approved'},
#    'revision_id': 'afbb8c35-fcf8-44e1-a0b3-5d87f199ab7d'}],
#  'num_followers': 4,
#  'id': '27cd857f-fec2-474d-b582-a263033938cb',
#  'tags': [],
#  'approval_status': 'approved'}

# %% [markdown]
# ## АРІ INSPECTIONS

# %% [markdown]
# https://docs.google.com/document/d/1YQMEEFf_EtuZMud2OVYeVpi3aDE6lsuUqFrsbzS5RKk/edit - документація
# https://inspections.gov.ua/ - інспекційний портал
#
# 360d858edaac8313a73d237f340138c097ab6304 - тестовий ключ (обмеження - 100 запитів на годину) (https://inspections.gov.ua/article/view?id=30)
#
# https://inspections.gov.ua/dashboard/#/basic - аналітичний модуль

# %%
lists = requests.get("http://api.ias.brdo.com.ua/v1_1/inspection?apiKey=360d858edaac8313a73d237f340138c097ab6304&orderBy=desc").json()

# %%
lists
# Out:
# {'status': 'success',
#  'result_count': 50,
#  'items': [{'id': '3db43caf71e3122205b19a896159f270ec09fd7e',
#    'internal_id': 2552141,
#    'last_modify': '29-03-2021 13:26',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань безпечності харчових продуктів та захисту споживачів',
#    'regulator': 'Головне управління Держпродспоживслужби в Київській області',
#    'regions': False,
#    'data': {'name': 'ЯСНОГОРОДСЬКА ЗАГАЛЬНООСВІТНЯ ШКОЛА I-III СТУПЕНІВ ДИМЕРСЬКОЇ СЕЛИЩНОЇ РАДИ ВИШГОРОДСЬКОГО РАЙОНУ КИЇВСЬКОЇ ОБЛАСТІ',
#     'address': 'Україна, 07324, Київська обл., Вишгородський р-н, село Ясногородка, ВУЛИЦЯ КОЛЕКТИВНА, будинок 20-Б',
#     'code': '25301872',
#     'date_start': '2021-02-05 00:00:00',
#     'time_start': '',
#     'date_finish': '2021-02-05',
#     'time_finish': '',
#     'activity_type': 'перевірка вимог припису',
#     'timing': '1',
#     'risk': False,
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552141',
#     'result_act_date': '2021-02-05',
#     'result_act_number': '10-21.3.20-09/19',
#     'result_act': False,
#     'sphere': 'Державний нагляд (контроль) за дотриманням вимог санітарного законодавства',
#     'sphere_id': 111,
#     'inspectors': [{'pib': 'Мицик Лариса Василівна',
#       'position': 'Начальник відділу державного нагляду за дотриманням санітарного законодавтсва Вишгородського районного управління, державний інспектор',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Ткач Олена',
#     'subject_person_position': 'в. о. директора',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Перевірка виконання суб’єктом господарювання приписів, розпоряджень або інших розпорядчих документів щодо усунення порушень вимог законодавства'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-02-05'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ЯСНОГОРОДСЬКА ЗАГАЛЬНООСВІТНЯ ШКОЛА I-III СТУПЕНІВ ДИМЕРСЬКОЇ СЕЛИЩНОЇ РАДИ ВИШГОРОДСЬКОГО РАЙОНУ КИЇВСЬКОЇ ОБЛАСТІ',
#     'short_name': 'ЯСНОГОРОДСЬКА ЗОШ І-ІІІ СТ. ДИМЕРСЬКОЇ СЕЛИЩНОЇ РАДИ',
#     'address': 'Україна, 07324, Київська обл., Вишгородський р-н, село Ясногородка, ВУЛИЦЯ КОЛЕКТИВНА, будинок 20-Б',
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '1363d57c840dcb80f844c528e0846b34ab6f4fc5',
#    'internal_id': 2552139,
#    'last_modify': '29-03-2021 13:24',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань безпечності харчових продуктів та захисту споживачів',
#    'regulator': 'Головне управління Держпродспоживслужби у Львівській області',
#    'regions': False,
#    'data': {'name': 'ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ЛЬВІВГАЗ  ЗБУТ"',
#     'address': 'Україна, 79039, Львівська обл., місто Львів, вул.Шевченка Т., будинок 111А',
#     'code': '39594527',
#     'date_start': '2021-03-11 00:00:00',
#     'time_start': '10:30',
#     'date_finish': '2021-03-12',
#     'time_finish': '15:30',
#     'activity_type': 'Скарга Козик Н. П.',
#     'timing': '2',
#     'risk': 'Незначний',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552139',
#     'result_act_date': '2021-03-12',
#     'result_act_number': '0047',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078101',
#     'sphere': 'Державний нагляд (контроль) за додержанням законодавства про захист прав споживачів',
#     'sphere_id': 146,
#     'inspectors': [{'pib': 'Нуцковський Михайло Іванович',
#       'position': 'головний спеціаліст відділу контролю у сфері торгівлі, робіт та послуг',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Майк Павло Романович',
#     'subject_person_position': 'директор',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Звернення фізичної особи (фізичних осіб) про порушення, що спричинило шкоду її (їхнім) правам, законним інтересам, життю чи здоров’ю, навколишньому природному середовищу чи безпеці держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-12'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ЛЬВІВГАЗ  ЗБУТ"',
#     'short_name': 'ТОВ "ЛЬВІВГАЗ ЗБУТ"',
#     'address': 'Україна, 79039, Львівська обл., місто Львів, вул.Шевченка Т., будинок 111А',
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '6b26cffc559e2763ae36ad18d9b39529b86b7a77',
#    'internal_id': 2552136,
#    'last_modify': '29-03-2021 13:30',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Пенсійний фонд України',
#    'regulator': 'Головне управління Пенсійного фонду України у Кіровоградській області',
#    'regions': False,
#    'data': {'name': 'ПРИВАТНЕ НАВЧАЛЬНО-ВИХОВНЕ ОБ\'ЄДНАННЯ "ДОШКІЛЬНИЙ НАВЧАЛЬНИЙ ЗАКЛАД - СПЕЦІАЛІЗОВАНА ШКОЛА І-ІІ СТУПЕНІВ-ЛІЦЕЙ "ШКОЛА ОР-АВНЕР"',
#     'address': 'Україна, 25006, Кіровоградська обл., місто Кіровоград(п), ВУЛИЦЯ ДЗЕРЖИНСЬКОГО, будинок 90',
#     'code': '31203686',
#     'date_start': '2021-03-26 00:00:00',
#     'time_start': '09:00',
#     'date_finish': '2021-03-26',
#     'time_finish': '12:00',
#     'activity_type': 'Додержання законодавства у сфері загальнообов’язкового державного пенсійного страхування',
#     'timing': '1',
#     'risk': 'Незначний',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552136',
#     'result_act_date': '2021-03-26',
#     'result_act_number': '108',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078107',
#     'sphere': "Провадження господарської діяльності у сфері загальнообов'язкового державного пенсійного страхування",
#     'sphere_id': 134,
#     'inspectors': [{'pib': 'Калько Тетяна Микитівна',
#       'position': 'головний спеціаліст',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Зіненко Олена Віталіївна',
#     'subject_person_position': 'директор',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Подання суб’єктом господарювання письмової заяви про здійснення заходу державного нагляду (контролю) за його бажанням'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-26'},
#     'violations': [{'id': 2655143,
#       'description': 'До реєстру застрахованих осіб Державного реєстру загальнообов’язкового державного соціального страхування подано недостовірні відомості про застраховану особу відповідно до акту перевірки',
#       'documents': [{'document': "Про загальнообов'язкове державне пенсійне страхування",
#         'document_part': "частина третя, частина п'ята статті 21"}]}],
#     'document': [{'type': False,
#       'date': '2021-03-26',
#       'number': '86',
#       'person_who_signed': 'Калько Тетяна Микитівна',
#       'violations': [{'violation_id': 2655143,
#         'action_for_correction': 'У місячний термін необхідно подати відомості про застраховану особу для внесення до реєстру застрахованих осіб Державного реєстру загальнообов’язкового державного соціального страхування,  відповідно до акту перевірки від 26 березня 2021 року №108',
#         'term': 'в місячний термін',
#         'term_extended': None,
#         'is_violation_corrected': 'Ні'}],
#       'appeal': {'date': False,
#        'result_status': False,
#        'result_date': False,
#        'result_number': ''},
#       'appeal_court': False,
#       'status': 'Не виконано',
#       'administrative_document_file': 'https://cdn.inspections.gov.ua/inspection/1078107',
#       'note': False}],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ПРИВАТНЕ НАВЧАЛЬНО-ВИХОВНЕ ОБ\'ЄДНАННЯ "ДОШКІЛЬНИЙ НАВЧАЛЬНИЙ ЗАКЛАД - СПЕЦІАЛІЗОВАНА ШКОЛА І-ІІ СТУПЕНІВ-ЛІЦЕЙ "ШКОЛА ОР-АВНЕР"',
#     'short_name': 'НВО "ШКОЛА ОР-АВНЕР"',
#     'address': 'Україна, 25006, Кіровоградська обл., місто Кіровоград(п), ВУЛИЦЯ ДЗЕРЖИНСЬКОГО, будинок 90',
#     'phone': '0951845597',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '14b90eeae60c2b9c029499bdbc4f41069a98b679',
#    'internal_id': 2552134,
#    'last_modify': '29-03-2021 13:23',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з надзвичайних ситуацій',
#    'regulator': 'Головне управління ДСНС у м. Києві',
#    'regions': False,
#    'data': {'name': 'ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ПАРК-ГОТЕЛЬ "КИЇВ"',
#     'address': 'Україна, 04075, місто Київ, ВУЛИЦЯ МИКОЛИ ЮНКЕРОВА, будинок 20',
#     'code': '35199464',
#     'date_start': '2021-03-15 00:00:00',
#     'time_start': '',
#     'date_finish': '2021-03-26',
#     'time_finish': '',
#     'activity_type': 'Дотримання законодавства в сфері техногенної, пожежної безпеки та цивільного захисту',
#     'timing': '10',
#     'risk': False,
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552134',
#     'result_act_date': '2021-03-26',
#     'result_act_number': '156',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078075',
#     'sphere': 'Техногенна та пожежна безпека, цивільний захист і діяльність аварійно-рятувальних служб',
#     'sphere_id': 119,
#     'inspectors': [{'pib': 'Єрко Антон Сергійович',
#       'position': 'головний інспектор відділу запобігання надзвичайним ситуаціям та ЗЦЗ Оболонського РУ ГУ ДСНС України у м. Києві',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': '',
#     'subject_person_position': '',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-26'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ПАРК-ГОТЕЛЬ "КИЇВ"',
#     'short_name': 'ТОВ "ПАРК-ГОТЕЛЬ "КИЇВ"',
#     'address': 'Україна, 04075, місто Київ, ВУЛИЦЯ МИКОЛИ ЮНКЕРОВА, будинок 20',
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': 'cd4f15045c8a766f0285ce30f59609c85ff570ef',
#    'internal_id': 2552133,
#    'last_modify': '29-03-2021 13:33',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань безпечності харчових продуктів та захисту споживачів',
#    'regulator': 'Головне управління Держпродспоживслужби в Рівненській області',
#    'regions': False,
#    'data': {'name': 'ЗАКЛАД ДОШКІЛЬНОЇ ОСВІТИ (ЯСЛА-САДОК) №55 РІВНЕНСЬКОЇ МІСЬКОЇ РАДИ',
#     'address': 'Україна, 33016, Рівненська обл., місто Рівне, ВУЛИЦЯ РОМАНА ШУХЕВИЧА, будинок 28',
#     'code': '25317369',
#     'date_start': '2021-03-23 00:00:00',
#     'time_start': '',
#     'date_finish': '2021-03-23',
#     'time_finish': '',
#     'activity_type': 'Додержання законодавства у сфері санітарного та епідемічного благополуччя',
#     'timing': '1',
#     'risk': 'Високий',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552133',
#     'result_act_date': '2021-03-23',
#     'result_act_number': 'б/н',
#     'result_act': False,
#     'sphere': 'Державний нагляд (контроль) за дотриманням вимог санітарного законодавства',
#     'sphere_id': 111,
#     'inspectors': [{'pib': 'Грабовський Сергій Федорович',
#       'position': 'начальник відділу державного нагляду за дотриманням санітарного законодавства Рівненського міського управління Головного управління Держпродспоживслужби в Рівненській області',
#       'prof_competence': False,
#       'goodness': False},
#      {'pib': False,
#       'position': False,
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Ходакова Наталія Володимирівна',
#     'subject_person_position': 'директор',
#     'subject_other_persons': [{'pib': 'Короткова Наталія Іванівна',
#       'position': 'сестра медична старша'}],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-23'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ЗАКЛАД ДОШКІЛЬНОЇ ОСВІТИ (ЯСЛА-САДОК) №55 РІВНЕНСЬКОЇ МІСЬКОЇ РАДИ',
#     'short_name': 'ЗДО №55',
#     'address': 'Україна, 33016, Рівненська обл., місто Рівне, ВУЛИЦЯ РОМАНА ШУХЕВИЧА, будинок 28',
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '14aa9aa186260075c9e1779066e47203d961519a',
#    'internal_id': 2552132,
#    'last_modify': '29-03-2021 13:50',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 2,
#    'parent_regulator': 'Державна служба якості освіти України',
#    'regulator': 'Управління Державної служби якості освіти у Київській області',
#    'regions': False,
#    'data': {'name': 'КОМУНАЛЬНИЙ ЗАКЛАД "ЛУБ\'ЯНСЬКИЙ ЗАКЛАД ДОШКІЛЬНОЇ ОСВІТИ КОМБІНОВАНОГО ТИПУ №9 "ВОЛОШКА" БУЧАНСЬКОЇ МІСЬКОЇ РАДИ КИЇВСЬКОЇ ОБЛАСТІ',
#     'address': "Україна, 07831, Київська обл., Бородянський р-н, село Луб'янка, ВУЛИЦЯ  ШЕВЧЕНКА, будинок 100",
#     'code': '21694260',
#     'date_start': '2021-03-22 00:00:00',
#     'time_start': '09:00',
#     'date_finish': '2021-03-26',
#     'time_finish': '17:00',
#     'activity_type': 'Додержання суб’єктом господарювання вимог законодавства у сфері дошкільної освіти з питань, визначених у формі Акта, затвердженого наказом Міністерства освіти і науки України від 05.08.2019 №1070',
#     'timing': '3',
#     'risk': False,
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552132',
#     'result_act_date': '2021-03-26',
#     'result_act_number': '02-05/01',
#     'result_act': False,
#     'sphere': 'Надання освітніх послуг у системі дошкільної освіти',
#     'sphere_id': 140,
#     'inspectors': [{'pib': 'Алексєєнко Лемовська Людмила Владиславівна',
#       'position': 'заступник начальника управління - начальник відділу інституційного аудиту управління Державної служби якості освіти у Київській області',
#       'prof_competence': False,
#       'goodness': False},
#      {'pib': 'Махонько Микита Русланович',
#       'position': 'головний спеціаліст відділу взаємодії з органами місцевого самоврядування, моніторингу та позапланового контролю закладів освіти управління Державної служби якості освіти у Київській області',
#       'prof_competence': False,
#       'goodness': False},
#      {'pib': 'Вербицька Віолета Василівна',
#       'position': 'головний спеціаліст відділу взаємодії з органами місцевого самоврядування, моніторингу та позапланового контролю закладів освіти управління Державної служби якості освіти у Київській області',
#       'prof_competence': False,
#       'goodness': False},
#      {'pib': 'Курочка Вікторія Андріївна',
#       'position': 'головний спеціаліст відділу дошкільної освіти Державної служби якості освіти України',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'ВИСОЦЬКА Лілія Миколаївна',
#     'subject_person_position': 'Директор закладу',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Звернення фізичної особи (фізичних осіб) про порушення, що спричинило шкоду її (їхнім) правам, законним інтересам, життю чи здоров’ю, навколишньому природному середовищу чи безпеці держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-26'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'КОМУНАЛЬНИЙ ЗАКЛАД "ЛУБ\'ЯНСЬКИЙ ЗАКЛАД ДОШКІЛЬНОЇ ОСВІТИ КОМБІНОВАНОГО ТИПУ №9 "ВОЛОШКА" БУЧАНСЬКОЇ МІСЬКОЇ РАДИ КИЇВСЬКОЇ ОБЛАСТІ',
#     'short_name': 'КЗЛЗДО №9 "ВОЛОШКА"',
#     'address': "Україна, 07831, Київська обл., Бородянський р-н, село Луб'янка, ВУЛИЦЯ  ШЕВЧЕНКА, будинок 100",
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '6429b5b4037426eb7093fc9d5b7ec718e7293de8',
#    'internal_id': 2552131,
#    'last_modify': '29-03-2021 13:26',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань праці',
#    'regulator': 'Управління Держпраці у Вінницькій області',
#    'regions': False,
#    'data': {'name': 'Браславський Юрій Семенович',
#     'address': '23800, Україна, 23800, Вінницька обл., Теплицький р-н, селище міського типу Теплик, ВУЛИЦЯ НЕЗАЛЕЖНОСТІ , будинок 45',
#     'code': 'ФОП',
#     'date_start': '2021-03-24 00:00:00',
#     'time_start': '15:10',
#     'date_finish': '2021-03-29',
#     'time_finish': '12:30',
#     'activity_type': 'Контроль за додержанням законодавства про працю',
#     'timing': '2',
#     'risk': 'Незначний',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552131',
#     'result_act_date': '2021-03-29',
#     'result_act_number': 'ВН 1624/477/ПД/АВ',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078108',
#     'sphere': 'Додержання законодавства про працю',
#     'sphere_id': 182,
#     'inspectors': [{'pib': 'Ветушинський Геннадій Іванович',
#       'position': 'Головний державний інспектор відділу з питань додержання законодавства про працю, зайнятість та інших нормативно-правових актів Управління Держпраці у Вінницькій області',
#       'prof_competence': False,
#       'goodness': False},
#      {'pib': 'Короленко Віктор Олегович',
#       'position': 'Головний державний інспектор відділу з питань додержання законодавства про працю, зайнятість та інших нормативно-правових актів Управління Держпраці у Вінницькій області',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Браслівський Юрій Семенович',
#     'subject_person_position': 'фізична особа-підприємець',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Так', 'subject_video': 'Так'},
#     'inspection_reasons': [{'document_reason_group': 'Постанова КМУ від 21.08.2019 №823 "Деякі питання здійснення державного нагляду та контролю за додержанням законодавства про працю"',
#       'reason_base': 'За дорученням Прем’єр-міністра України'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-29'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': 'ФОП',
#     'full_name': 'Браславський Юрій Семенович',
#     'short_name': 'Браславський Юрій Семенович',
#     'address': '23800, Україна, 23800, Вінницька обл., Теплицький р-н, селище міського типу Теплик, ВУЛИЦЯ НЕЗАЛЕЖНОСТІ , будинок 45',
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '157ed1fa0806aecdfdec2cc09d000b239f94be9e',
#    'internal_id': 2552130,
#    'last_modify': '29-03-2021 13:33',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з надзвичайних ситуацій',
#    'regulator': 'Головне управління ДСНС у м. Києві',
#    'regions': False,
#    'data': {'name': 'ТОВ "Управляюча компанія "ЛІСОВА"',
#     'address': 'місто Київ, Деснянський район, вул. Радистів 34К, 34Л, 34М, 34Н, 34П,34Р',
#     'code': '43594384',
#     'date_start': '2021-03-18 00:00:00',
#     'time_start': '',
#     'date_finish': False,
#     'time_finish': False,
#     'activity_type': 'птб',
#     'timing': '',
#     'risk': 'Високий',
#     'in_complex': None,
#     'status': 'Не проведено',
#     'status_reason_not_conducted': "Відсутність під час проведення заходу державного нагляду (контролю) керівника суб'єкта господарювання або уповноваженої ним особи",
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552130',
#     'result_act_date': '2021-03-19',
#     'result_act_number': '29/144',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078090',
#     'sphere': 'Техногенна та пожежна безпека, цивільний захист і діяльність аварійно-рятувальних служб',
#     'sphere_id': 119,
#     'inspectors': False,
#     'subject_person_pib': False,
#     'subject_person_position': False,
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Перевірка виконання суб’єктом господарювання приписів, розпоряджень або інших розпорядчих документів щодо усунення порушень вимог законодавства'}],
#     'act_received_info': {'act_received': 'Ні', 'date_received_date': False},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': False,
#    'new': 1},
#   {'id': '5868561754f01241b011782f603a0e759bfbd07c',
#    'internal_id': 2552129,
#    'last_modify': '29-03-2021 13:23',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань праці',
#    'regulator': 'Управління Держпраці у Кіровоградській області',
#    'regions': False,
#    'data': {'name': 'Гарник Катерина Володимирівна',
#     'address': '25028, Україна, 25028, Кіровоградська обл., місто Кіровоград(п), ВУЛИЦЯ  ВОЛКОВА, будинок 28, корпус 3, квартира 44',
#     'code': 'ФОП',
#     'date_start': '2021-03-25 00:00:00',
#     'time_start': '10:00',
#     'date_finish': '2021-03-26',
#     'time_finish': '13:00',
#     'activity_type': 'Додержання вимог законодавства про працю',
#     'timing': '2',
#     'risk': False,
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552129',
#     'result_act_date': '2021-03-26',
#     'result_act_number': 'КР3210/219/АВ',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078081',
#     'sphere': 'Зайнятість населення, зайнятість та працевлаштування осіб з інвалідністю',
#     'sphere_id': 131,
#     'inspectors': [{'pib': 'Махно Наталя Володимирівна',
#       'position': 'головний державний інспектор відділу з питань додержання законодавства про працю, зайнятість та інших нормативно-правових актів',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Гарник Катерина Володимирівна',
#     'subject_person_position': 'ФОП',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Неподання суб’єктом господарювання документів обов’язкової звітності за два звітні періоди підряд без поважних причин або без надання письмових пояснень про причини, що перешкоджали поданню таких документів'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-26'},
#     'violations': [{'id': 2655001,
#       'description': 'Порушення вимог ч.9 ст. 19 ЗУ «Про основи соціальної захищеності iнвалiдiв в Українi»  №875 якою передбачено, що керівники підприємств, установ, організацій, у тому числі підприємств, організацій громадських організацій осіб з інвалідністю, фізичні особи, які використовують найману працю, у разі незабезпечення виконання нормативів робочих місць для працевлаштування осіб з інвалідністю, неподання Фонду соціального захисту інвалідів звіту про зайнятість та працевлаштування осіб з інвалідністю несуть відповідальність у встановленому законом порядку.\r\n     Строки подання Фонду соціального захисту інвалідів звітів «Про зайнятість та працевлаштування інвалідів», зарахування кількості робочих місць для працевлаштування інвалідів, контролю за виконанням нормативів робочих місць та перевірки підприємств, які використовують найману працю, щодо їх реєстрації у Фонді соціального захисту інвалідів, його відділеннях, подачі щорічного звіту, а також надання державній службі зайнятості інформації, необхідної для організації працевлаштування інвалідів, визначених постановою Кабінетом Міністрів України від 31.01.2007 «Про реалізацію статей 19 і 20 Закону України «Про основи соціальної захищеності інвалідів в Україні».\r\nТак, звіти про зайнятість та працевлаштування інвалідів за 2019 та 2020 роки до Кіровоградського обласного відділення Фонду соціального захисту інвалідів ФОП подано з порушенням строків, а саме 23.03.2021, про що свідчить відмітка Фонду соціального захисту інвалідів. В той же час, згідно п. 2 Порядку подання підприємствами, установами, організаціями та фізичними особами, що використовують найману працю, звітів про зайнятість і працевлаштування осіб з інвалідністю та інформації, необхідної для організації їх працевлаштування, затвердженого постановою КМУ від 31.01.2007 №70 (зі змінами) (далі – Порядок) звіт подається роботодавцями щороку до 1 березня, наступного після звітного періоду. Датою надходження звіту про зайнятість і працевлаштування осіб з інвалідністю вважається дата подання роботодавцем звіту до відділення Фонду, а у разі надсилання його поштою - дата на поштовому штемпелі. (Копії звітів форми №10-ПОІ за 2019 та 2020 роки додаються).',
#       'documents': [{'document': 'Про основи соціальної захищеності інвалідів в Україні',
#         'document_part': 'частина дев’ята статті 19'}]}],
#     'document': [{'type': False,
#       'date': '2021-03-26',
#       'number': 'КР3210/219/АВ/П',
#       'person_who_signed': 'Махно Наталія Володимирівна',
#       'violations': [{'violation_id': 2655001,
#         'action_for_correction': '',
#         'term': '2021-04-15',
#         'term_extended': '',
#         'is_violation_corrected': ''}],
#       'appeal': {'date': False,
#        'result_status': False,
#        'result_date': False,
#        'result_number': ''},
#       'appeal_court': False,
#       'status': 'Не визначено',
#       'administrative_document_file': 'https://cdn.inspections.gov.ua/inspection/1078081',
#       'note': False}],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': 'ФОП',
#     'full_name': 'Гарник Катерина Володимирівна',
#     'short_name': 'Гарник Катерина Володимирівна',
#     'address': '25028, Україна, 25028, Кіровоградська обл., місто Кіровоград(п), ВУЛИЦЯ  ВОЛКОВА, будинок 28, корпус 3, квартира 44',
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '7e173a85e8d91409e3b33a71b340fc7bf40e66bb',
#    'internal_id': 2552128,
#    'last_modify': '29-03-2021 13:14',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань безпечності харчових продуктів та захисту споживачів',
#    'regulator': 'Головне управління Держпродспоживслужби в Рівненській області',
#    'regions': False,
#    'data': {'name': 'Куліковська Наталія Ярославівна',
#     'address': '35341, Україна, 35341, Рівненська обл., Рівненський р-н, село Городище, ВУЛИЦЯ ЛЕСІ УКРАЇНКИ, будинок 42',
#     'code': 'ФОП',
#     'date_start': '2021-03-19 00:00:00',
#     'time_start': '',
#     'date_finish': '2021-03-19',
#     'time_finish': '',
#     'activity_type': 'Додержання законодавства у сфері санітарного та епідемічного благополуччя',
#     'timing': '1',
#     'risk': 'Незначний',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552128',
#     'result_act_date': '2021-03-19',
#     'result_act_number': 'б/н',
#     'result_act': False,
#     'sphere': 'Державний нагляд (контроль) за дотриманням вимог санітарного законодавства',
#     'sphere_id': 111,
#     'inspectors': [{'pib': 'Грабовський Сергій Федорович',
#       'position': 'начальник відділу державного нагляду за дотриманням санітарного законодавства Рівненського міського управління Головного управління Держпродспоживслужби в Рівненській області',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Куліковська Наталія Ярославівна',
#     'subject_person_position': 'фізична особа-підприємець',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Подання суб’єктом господарювання письмової заяви про здійснення заходу державного нагляду (контролю) за його бажанням'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-19'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': 'ФОП',
#     'full_name': 'Куліковська Наталія Ярославівна',
#     'short_name': 'Куліковська Наталія Ярославівна',
#     'address': '35341, Україна, 35341, Рівненська обл., Рівненський р-н, село Городище, ВУЛИЦЯ ЛЕСІ УКРАЇНКИ, будинок 42',
#     'phone': '',
#     'email': '',
#     'subject_objects': [{'name': 'кабінет лікаря-офтальмолога',
#       'address': '33000, Рівненська область, місто Рівне, вулиця Міцкевича, будинок 32',
#       'type': 'приміщення медкабінету'}],
#     'subject_parted': False},
#    'new': 1},
#   {'id': 'f40d8258b4dd00522b0254cae77dbd876e6d4e6a',
#    'internal_id': 2552127,
#    'last_modify': '29-03-2021 13:30',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з надзвичайних ситуацій',
#    'regulator': 'Головне управління ДСНС у Харківській області',
#    'regions': False,
#    'data': {'name': 'ПРИВАТНЕ СІЛЬСЬКОГОСПОДАРСЬКЕ ПІДПРИЄМСТВО "ЦАРЕДАРІВСЬКЕ"',
#     'address': 'Україна, 64661, Харківська обл., Лозівський р-н, село Царедарівка',
#     'code': '32414100',
#     'date_start': '2021-03-22 00:00:00',
#     'time_start': '09:00',
#     'date_finish': '2021-03-26',
#     'time_finish': '17:00',
#     'activity_type': 'Додержання (виконання) вимог законодавства у сфері техногенної та пожежної безпеки',
#     'timing': '5',
#     'risk': 'Високий',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552127',
#     'result_act_date': '2021-03-26',
#     'result_act_number': '23',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078084',
#     'sphere': 'Техногенна та пожежна безпека, цивільний захист і діяльність аварійно-рятувальних служб',
#     'sphere_id': 119,
#     'inspectors': [{'pib': 'Берко Ігор Володимирович',
#       'position': 'провідний інспектор Лозівського районного відділу ГУ ДСНС України у Харківській області',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Більовцов Станіслав Володимирович',
#     'subject_person_position': 'представник керівника ПСП «Царедарівське»',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-26'},
#     'violations': [{'id': 2654950,
#       'description': 'Територія об’єкта, а також будинки, споруди, приміщення не забезпечені відповідними знаками безпеки',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Пункт 8 розділу ІІ'}]},
#      {'id': 2654955,
#       'description': 'Посадові особи та працівники не пройшли навчання та перевірку знань з питань пожежної безпеки у порядку, встановленому законодавством',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Пункт 16 розділу ІІ'}]},
#      {'id': 2654962,
#       'description': 'Дерев’яні елементи горищного покриття (крокви, лати) офісної будівлі не оброблено засобами вогнезахисту, які забезпечують І групу вогнезахисної ефективності\r\n(підтверджується – відсутністю акту приймання виконаних робіт з вогнезахисного оброблення)',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Пункт 2.5 глави 2 розділу ІІІ'}]},
#      {'id': 2654968,
#       'description': 'Для всіх будівель і приміщень складського призначення не визначені категорія щодо вибухопожежної та пожежної небезпеки відповідно до вимог ДСТУ Б В.1.1-36:2016 «Визначення категорій приміщень, будинків та зовнішніх установок за вибухопожежною та пожежною небезпекою»,',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Пункт 2.9 глави 2 розділу ІІІ'}]},
#      {'id': 2654972,
#       'description': 'В приміщені майстерні та заправного пункту  електропровід прокладено по горючій основі\r\n(підтверджується – фото)',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Абзац другий пункту 1.12 глави 1 розділу IV'}]},
#      {'id': 2654978,
#       'description': 'З’єднання, відгалуження та окінцювання жил проводів і кабелів в приміщені майстерні здійснюється не за допомогою опресування, зварювання, паяння або затискачів',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Абзац перший пункту 1.6 глави 1 розділу IV'}]},
#      {'id': 2654981,
#       'description': 'Електричні розетки, вмикачі в приміщеннях майстерні та заправного пункту встановленні на горючій основі',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Пункт 1.17, глава 1, розділ ІV'}]},
#      {'id': 2654984,
#       'description': 'Будівлі складів не обладнано системами протипожежного захисту відповідно до ДБН В.2.5-56:2014 «Системи протипожежного захисту»',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'пункт 1.2 глави 1 розділу V'}]},
#      {'id': 2654987,
#       'description': 'Підприємство не в повній мірі забезпечено вогнегасниками',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Пункт 3.6 глави 3\r\n розділу V'}]},
#      {'id': 2654990,
#       'description': 'На підприємстві не виконано технічне обслуговування наявних вогнегасників',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Пункт 3.17 глави 3 розділу V'}]},
#      {'id': 2654994,
#       'description': 'Не виконано обвалування складського майданчику ПММ',
#       'documents': [{'document': 'Про затвердження Правил пожежної безпеки в Україні',
#         'document_part': 'Підпункти 2, 25 пункту 9.2 глави 9 розділу VІ'}]},
#      {'id': 2654999,
#       'description': 'Керівником не забезпечено відповідно до законодавства своїх працівників засобами колективного та індивідуального захисту',
#       'documents': [{'document': 'Про затвердження Правил техногенної безпеки',
#         'document_part': 'Абзац третій пункту 2 розділу ІІІ'}]},
#      {'id': 2655005,
#       'description': 'Підприємство не забезпечене аварійно-рятувальним обслуговуванням',
#       'documents': [{'document': 'Кодекс цивільного захисту України',
#         'document_part': 'Пункт 12 частини першої статті 20'}]},
#      {'id': 2655010,
#       'description': 'Не надано суб’єктом господарювання декларації відповідності матеріально-технічної бази суб’єкта господарювання вимогам законодавства з питань пожежної безпеки',
#       'documents': [{'document': 'Кодекс цивільного захисту України',
#         'document_part': 'Абзац перший частини другої статті 57'}]},
#      {'id': 2655015,
#       'description': 'Відсутній інформаційно-довідковий куточок з питань цивільного захисту',
#       'documents': [{'document': 'Кодекс цивільного захисту України',
#         'document_part': 'Пункт 3 статті 40'}]},
#      {'id': 2655020,
#       'description': 'Не проведено ідентифікацію об’єкта з урахуваннях всіх джерел небезпеки',
#       'documents': [{'document': "Про затвердження Методики ідентифікації потенційно небезпечних об'єктів",
#         'document_part': 'Пункти 2,9'}]}],
#     'document': [{'type': False,
#       'date': '2021-03-26',
#       'number': '22',
#       'person_who_signed': 'Провідний інспектор Лозівського РВ ГУ ДСНС України у Харківській області Берко Ігор Володимирович',
#       'violations': [{'violation_id': 2654950,
#         'action_for_correction': 'Територія об’єкта, а також будинки, споруди, приміщення  забезпечити відповідними знаками безпеки',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654955,
#         'action_for_correction': 'Посадовим особам та працівникам пройти навчання та перевірку знань з питань пожежної безпеки у порядку, встановленому законодавством',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654962,
#         'action_for_correction': 'Дерев’яні елементи горищного покриття (крокви, лати) офісної будівлі обробити засобами вогнезахисту, які забезпечують І групу вогнезахисної ефективності\r\n(підтверджується – відсутністю акту приймання виконаних робіт з вогнезахисного оброблення)\r\n',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654968,
#         'action_for_correction': 'Для всіх будівель і приміщень складського призначення визначити категорію щодо вибухопожежної та пожежної небезпеки відповідно до вимог ДСТУ Б В.1.1-36:2016 «Визначення категорій приміщень, будинків та зовнішніх установок за вибухопожежною та пожежною небезпекою»',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654972,
#         'action_for_correction': 'В приміщені майстерні та заправного пункту  електропровід прокласти по не горючій основі\r\n(підтверджується – фото)\r\n',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654978,
#         'action_for_correction': 'З’єднання, відгалуження та окінцювання жил проводів і кабелів в приміщені майстерні здійснити за допомогою опресування, зварювання, паяння або затискачів',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654981,
#         'action_for_correction': 'Електричні розетки, вмикачі в приміщеннях майстерні та заправного пункту встановити на не горючі основи.',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654984,
#         'action_for_correction': 'Будівлі складів обладнати системами протипожежного захисту відповідно до ДБН В.2.5-56:2014 «Системи протипожежного захисту»',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654987,
#         'action_for_correction': 'Забезпечити підприємство в повній мірі вогнегасниками ',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654990,
#         'action_for_correction': 'Виконати технічне обслуговування наявних вогнегасників',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654994,
#         'action_for_correction': 'Виконати обвалування складського майданчику ПММ',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2654999,
#         'action_for_correction': 'Керівником забезпечити відповідно до законодавства своїх працівників засобами колективного та індивідуального захисту ',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2655005,
#         'action_for_correction': 'Заключити договір на аварійно-рятувальним обслуговуванням',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2655010,
#         'action_for_correction': 'Надати декларацію відповідності матеріально-технічної бази суб’єкта господарювання вимогам законодавства з питань пожежної безпеки',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2655015,
#         'action_for_correction': 'Встановити інформаційно-довідковий куточок з питань цивільного захисту',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''},
#        {'violation_id': 2655020,
#         'action_for_correction': 'Провести ідентифікацію об’єкта з урахуваннях всіх джерел небезпеки',
#         'term': '26.05.2021',
#         'term_extended': '',
#         'is_violation_corrected': ''}],
#       'appeal': {'date': False,
#        'result_status': False,
#        'result_date': False,
#        'result_number': ''},
#       'appeal_court': False,
#       'status': 'Не визначено',
#       'administrative_document_file': 'https://cdn.inspections.gov.ua/inspection/1078084',
#       'note': False}],
#     'sanction': [{'is_document_not_done': None,
#       'violation_id': None,
#       'document': 'Кодекс України про адміністративні правопорушення',
#       'document_part': '188 8',
#       'type_label': 'Штраф, який визначається уповноваженим органом (посадовою особою) у межах, встановлених законом',
#       'type': 'fine_regulator',
#       'negative_efects_type': '',
#       'has_effect': 0,
#       'regulator': {'document_type': 'Постанова',
#        'document_date': '2021-03-26',
#        'document_number': 'ХА 034940',
#        'sanction_fine_amount': None,
#        'sanction_cancellation_date': None,
#        'sanction_cancellation_number': None,
#        'sanction_cancellation_term': None,
#        'sanction_property_description': None,
#        'sanction_amount': None,
#        'appeal': False}}],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ПРИВАТНЕ СІЛЬСЬКОГОСПОДАРСЬКЕ ПІДПРИЄМСТВО "ЦАРЕДАРІВСЬКЕ"',
#     'short_name': 'ПСП "ЦАРЕДАРІВСЬКЕ"',
#     'address': 'Україна, 64661, Харківська обл., Лозівський р-н, село Царедарівка',
#     'phone': '',
#     'email': '',
#     'subject_objects': [{'name': 'СІЛЬСЬКОГОСПОДАРСЬКЕ ПІДПРИЄМСТВО "ЦАРЕДАРІВСЬКЕ"',
#       'address': '64661, Харківська область, Лозівський район, с. Царедарівка',
#       'type': 'Будівлі сільськогосподарського призначення інші'}],
#     'subject_parted': False},
#    'new': 1},
#   {'id': 'b4526004e361da4b6a87cb7720293ce18a44254c',
#    'internal_id': 2552125,
#    'last_modify': '29-03-2021 13:15',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань безпечності харчових продуктів та захисту споживачів',
#    'regulator': 'Головне управління Держпродспоживслужби у Львівській області',
#    'regions': False,
#    'data': {'name': 'ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ЛЬВІВГАЗ  ЗБУТ"',
#     'address': 'Україна, 79039, Львівська обл., місто Львів, вул.Шевченка Т., будинок 111А',
#     'code': '39594527',
#     'date_start': '2021-03-11 00:00:00',
#     'time_start': '10:30',
#     'date_finish': '2021-03-12',
#     'time_finish': '15:30',
#     'activity_type': 'Скарга Скоринович А.І.',
#     'timing': '3',
#     'risk': 'Незначний',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552125',
#     'result_act_date': '2021-03-12',
#     'result_act_number': '0048',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1078052',
#     'sphere': 'Державний нагляд (контроль) за додержанням законодавства про захист прав споживачів',
#     'sphere_id': 146,
#     'inspectors': [{'pib': 'Сімонов Роман Романович',
#       'position': 'головний спеціаліст відділу ринкового та метрологічного нагляду Управління захисту споживачів',
#       'prof_competence': False,
#       'goodness': False},
#      {'pib': 'Нуцковський Михайло Іванович',
#       'position': 'головний спеціаліст відділу контролю у сфері торгівлі, робіт та послуг',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Майк Павло Романович',
#     'subject_person_position': 'директор',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Звернення фізичної особи (фізичних осіб) про порушення, що спричинило шкоду її (їхнім) правам, законним інтересам, життю чи здоров’ю, навколишньому природному середовищу чи безпеці держави'}],
#     'act_received_info': {'act_received': 'Так',
# ...
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Харлан Марина Миколаївна',
#     'subject_person_position': 'касир-контролер',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-23'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': False,
#    'new': 1},
#   {'id': 'd71db965575224057b381005d92563e2838b4813',
#    'internal_id': 2552069,
#    'last_modify': '29-03-2021 12:33',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань безпечності харчових продуктів та захисту споживачів',
#    'regulator': 'Головне управління Держпродспоживслужби в Запорізькій області',
#    'regions': False,
#    'data': {'name': 'Можерін Олександр Олегович',
#     'address': '72319, Україна, 72319, Запорізька обл., місто Мелітополь, ВУЛИЦЯ ГЕРОЇВ УКРАЇНИ, будинок 67, квартира 43',
#     'code': 'ФОП',
#     'date_start': '2021-03-22 00:00:00',
#     'time_start': '13:00',
#     'date_finish': '2021-03-23',
#     'time_finish': '10:00',
#     'activity_type': 'Дотримання вимог санітарного законодавства0975141842',
#     'timing': '1',
#     'risk': 'Незначний',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552069',
#     'result_act_date': '2021-03-23',
#     'result_act_number': '268/29',
#     'result_act': False,
#     'sphere': 'Державний нагляд (контроль) за дотриманням вимог санітарного законодавства',
#     'sphere_id': 111,
#     'inspectors': [{'pib': 'Морозова Наталія Володимирівна',
#       'position': 'Начальник відділу державного нагляду за дотриманням санітарного законодавства Мелітопольського міського управління Головного управління Держпродспоживслужби в Запорізькій області',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Можерін Олександр Олегович',
#     'subject_person_position': 'Фізична особа-підприємець',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Подання суб’єктом господарювання письмової заяви про здійснення заходу державного нагляду (контролю) за його бажанням'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-23'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': 'ФОП',
#     'full_name': 'Можерін Олександр Олегович',
#     'short_name': 'Можерін Олександр Олегович',
#     'address': '72319, Україна, 72319, Запорізька обл., місто Мелітополь, ВУЛИЦЯ ГЕРОЇВ УКРАЇНИ, будинок 67, квартира 43',
#     'phone': '0975141842',
#     'email': '',
#     'subject_objects': [{'name': 'Стоматологічний кабінет ФОП Можерін О. О.',
#       'address': '72319, Запорізька обл., м. Мелітополь, вул. Монастирська, 25',
#       'type': False}],
#     'subject_parted': False},
#    'new': 1},
#   {'id': '136c211c43eff9840e48d6c78c04d4bf00dd79cc',
#    'internal_id': 2552068,
#    'last_modify': '29-03-2021 12:27',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з надзвичайних ситуацій',
#    'regulator': 'Головне управління ДСНС у Харківській області',
#    'regions': False,
#    'data': {'name': 'Кондратенко Ігор Володимирович',
#     'address': '61184, Україна, 61184, Харківська обл., місто Харків, ВУЛИЦЯ ДРУЖБИ НАРОДІВ, будинок 218, квартира 74',
#     'code': 'ФОП',
#     'date_start': '2021-03-25 00:00:00',
#     'time_start': '',
#     'date_finish': False,
#     'time_finish': False,
#     'activity_type': 'Додержання і виконання вимог, законодавства у сфері цивільного захисту, пожежної та техногенної безпеки',
#     'timing': '',
#     'risk': 'Високий',
#     'in_complex': None,
#     'status': 'Не проведено',
#     'status_reason_not_conducted': "Господарську діяльність суб'єкта господарювання припинено повністю або у частині, що підлягає державному нагляду (контролю)",
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552068',
#     'result_act_date': '2021-03-26',
#     'result_act_number': '42',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1077843',
#     'sphere': 'Техногенна та пожежна безпека, цивільний захист і діяльність аварійно-рятувальних служб',
#     'sphere_id': 119,
#     'inspectors': False,
#     'subject_person_pib': False,
#     'subject_person_position': False,
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Ні', 'date_received_date': False},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': 'ФОП',
#     'full_name': 'Кондратенко Ігор Володимирович',
#     'short_name': 'Кондратенко Ігор Володимирович',
#     'address': '61184, Україна, 61184, Харківська обл., місто Харків, ВУЛИЦЯ ДРУЖБИ НАРОДІВ, будинок 218, квартира 74',
#     'phone': '',
#     'email': '',
#     'subject_objects': [{'name': 'Style',
#       'address': '61033, м. Харків, вул. Шевченка, 194/196.',
#       'type': 'Готелі'}],
#     'subject_parted': False},
#    'new': 1},
#   {'id': 'd364a4f0d6ee8c106c66db2eb885c25e322ea9a5',
#    'internal_id': 2552067,
#    'last_modify': '29-03-2021 12:30',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з надзвичайних ситуацій',
#    'regulator': 'Управління ДСНС у Черкаській області',
#    'regions': False,
#    'data': {'name': 'ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "БІЗНЕС-ОІЛ-ГРУП"',
#     'address': 'Україна, 04112, місто Київ, ВУЛИЦЯ БАГГОВУТІВСЬКА, будинок 17-21',
#     'code': '40516502',
#     'date_start': '2021-03-25 00:00:00',
#     'time_start': '',
#     'date_finish': False,
#     'time_finish': False,
#     'activity_type': 'додержання вимог законодавства у сфері техногеної та пожежної безпеки',
#     'timing': '',
#     'risk': 'Високий',
#     'in_complex': None,
#     'status': 'Не проведено',
#     'status_reason_not_conducted': 'Суб’єкт господарювання ТОВ "БІЗНЕС-ОІЛ-ГРУП"за адресою: Черкаська область, Черкаський (Городищенський) район,  с. Хлистунівка, вул.  Шполянська, 45 припинив свою діяльність.',
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552067',
#     'result_act_date': '2021-03-26',
#     'result_act_number': '8',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1077856',
#     'sphere': 'Техногенна та пожежна безпека, цивільний захист і діяльність аварійно-рятувальних служб',
#     'sphere_id': 119,
#     'inspectors': False,
#     'subject_person_pib': False,
#     'subject_person_position': False,
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Ні', 'date_received_date': False},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "БІЗНЕС-ОІЛ-ГРУП"',
#     'short_name': 'ТОВ "БІЗНЕС-ОІЛ-ГРУП"',
#     'address': 'Україна, 04112, місто Київ, ВУЛИЦЯ БАГГОВУТІВСЬКА, будинок 17-21',
#     'phone': '',
#     'email': '',
#     'subject_objects': False,
#     'subject_parted': False},
#    'new': 1},
#   {'id': '8ad86be1748afe5ec36eb6060e9fdbb1310cd20d',
#    'internal_id': 2552066,
#    'last_modify': '29-03-2021 12:39',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з надзвичайних ситуацій',
#    'regulator': 'Управління ДСНС у Житомирській області',
#    'regions': False,
#    'data': {'name': 'ПІДПРИЄМСТВО З ІНОЗЕМНИМИ ІНВЕСТИЦІЯМИ "АМІК УКРАЇНА"',
#     'address': 'Україна, 04071, місто Київ, ВУЛИЦЯ ВЕРХНІЙ ВАЛ, будинок 68',
#     'code': '30603572',
#     'date_start': '2021-03-22 00:00:00',
#     'time_start': '09:00',
#     'date_finish': '2021-03-26',
#     'time_finish': '09:00',
#     'activity_type': 'Додержання та виконання вимог законодавства у сфері техногенної та пожежної безпеки',
#     'timing': '5',
#     'risk': 'Високий',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552066',
#     'result_act_date': '2021-03-26',
#     'result_act_number': '36',
#     'result_act': 'https://cdn.inspections.gov.ua/inspection/1077886',
#     'sphere': 'Техногенна та пожежна безпека, цивільний захист і діяльність аварійно-рятувальних служб',
#     'sphere_id': 119,
#     'inspectors': [{'pib': 'Гальчук Катерина Олександрівна',
#       'position': 'Провідний фахівець Малинського міськрайонного відділу Управління ДСНС України в Житомирській області',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Михайленко Олександр Сергійович',
#     'subject_person_position': 'Начальник автозаправочної станції 0607 ПІІ "Амік Україна"',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-06'},
#     'violations': [{'id': 2653982,
#       'description': 'На автомобільній автозаправочній станції 0607 не впроваджено  автоматизовану систему раннього виявлення надзвичайних ситуацій та систему оповіщення і не забезпечено їх працездатність.',
#       'documents': [{'document': 'Кодекс цивільного захисту України',
#         'document_part': 'Стаття 53'}]}],
#     'document': [{'type': False,
#       'date': '2021-03-26',
#       'number': '30',
#       'person_who_signed': 'Гальчук Катерина Олександрівна',
#       'violations': [{'violation_id': 2653982,
#         'action_for_correction': '',
#         'term': '2021-04-26',
#         'term_extended': '',
#         'is_violation_corrected': ''}],
#       'appeal': {'date': False,
#        'result_status': False,
#        'result_date': False,
#        'result_number': ''},
#       'appeal_court': False,
#       'status': 'Не визначено',
#       'administrative_document_file': 'https://cdn.inspections.gov.ua/inspection/1077886',
#       'note': False}],
#     'sanction': [],
#     'subject': False},
#    'subject': {'code': False,
#     'full_name': 'ПІДПРИЄМСТВО З ІНОЗЕМНИМИ ІНВЕСТИЦІЯМИ "АМІК УКРАЇНА"',
#     'short_name': 'ПІІ "АМІК УКРАЇНА"',
#     'address': 'Україна, 04071, місто Київ, ВУЛИЦЯ ВЕРХНІЙ ВАЛ, будинок 68',
#     'phone': '0445939300',
#     'email': 'info@amicenergy.com.ua',
#     'subject_objects': [{'name': 'ПІІ "АМІК - Україна"',
#       'address': '11640, Житомирська область, Малинський район, с.Жовтневе, (траса Київ-Ковель-Ягодин, 116 км + 550м. )',
#       'type': False}],
#     'subject_parted': False},
#    'new': 1},
#   {'id': '0e0d9821c01010ec0212892f128e4450b71e5ca4',
#    'internal_id': 2552064,
#    'last_modify': '29-03-2021 12:25',
#    'year': 2021,
#    'is_planned': 0,
#    'is_approved': 1,
#    'publish_status': 3,
#    'parent_regulator': 'Державна служба України з питань безпечності харчових продуктів та захисту споживачів',
#    'regulator': 'Головне управління Держпродспоживслужби в Житомирській області',
#    'regions': False,
#    'data': {'name': 'ПСК "Овруцький кооперативний  ринок"    ',
#     'address': 'Житомирська область м.Овруч вул.Базарна, 6',
#     'code': '01559079',
#     'date_start': '2021-03-21 00:00:00',
#     'time_start': '12:20',
#     'date_finish': '2021-03-21',
#     'time_finish': '13:00',
#     'activity_type': 'Закон України "Про забезпечення санітарного та епідемічного благополуччя населення", Закон України "Про захист населення від інфекційних хвороб", Постанова головного державного санітарного лікаря України від 06.06.2020 №34 «Про  затвердження  Тимчасових  рекомендацій  щодо  організації  протиепідемічних  заходів  з  торгівлі  на  ринках  на  період  карантину  у  зв’язку з  поширенням коронавірусної хвороби COVID-19»',
#     'timing': '1',
#     'risk': 'Незначний',
#     'in_complex': None,
#     'status': 'Проведено',
#     'status_reason_not_conducted': False,
#     'link': 'https://inspections.gov.ua/inspection/view?id=2552064',
#     'result_act_date': '2021-03-21',
#     'result_act_number': '113',
#     'result_act': False,
#     'sphere': 'Державний нагляд (контроль) за дотриманням вимог санітарного законодавства',
#     'sphere_id': 111,
#     'inspectors': [{'pib': 'Могилевець Інна Миколаївна',
#       'position': 'Фельдшер санітарний відділу державного нагляду за дотриманням санітарного законодавства Овруцького районного управління Головного управління Держпродспоживслужби в Житомирській області',
#       'prof_competence': False,
#       'goodness': False}],
#     'subject_person_pib': 'Харлан Марина Миколаївна',
#     'subject_person_position': 'касир-контролер',
#     'subject_other_persons': [],
#     'subject_event_process': {'subject_audio': 'Ні', 'subject_video': 'Ні'},
#     'inspection_reasons': [{'document_reason_group': 'ЗУ "Про основні засади державного нагляду (контролю) у сфері господарської діяльності" від 05.04.2007 № 877-V',
#       'reason_base': 'Доручення Прем’єр-міністра України про перевірку суб’єктів господарювання у відповідній сфері у зв’язку з виявленими системними порушеннями та/або настанням події, що має значний негативний вплив на права, законні інтереси, життя та здоров’я людини, захист навколишнього природного середовища та забезпечення безпеки держави'}],
#     'act_received_info': {'act_received': 'Так',
#      'date_received_date': '2021-03-21'},
#     'violations': [],
#     'document': [],
#     'sanction': [],
#     'subject': False},
#    'subject': False,
#    'new': 1}]}

# %% [markdown]
# ## API ProzorroSales
